# %% [markdown]
# <a href="https://colab.research.google.com/github/KostasTheOne/PyDex/blob/main/Profitable_Apps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Profitable App Analysis

# %% [markdown]
# Our goal for this project is to analysedata to understand what type of apps are likely to attract more users.

# %%
import pandas as pd
